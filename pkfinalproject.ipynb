# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df=sns.load_dataset('penguins')

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# **1.read.csv**

# %%
p=pd.read_csv("penguins.project.csv")

# %%
p
# Out:
#      Unnamed: 0    species     island  bill_length_mm  bill_depth_mm  \
# 0             1     Adelie  Torgersen            39.1           18.7
# 1             2     Adelie  Torgersen            39.5           17.4
# 2             3     Adelie  Torgersen            40.3           18.0
# 3             4     Adelie  Torgersen             NaN            NaN
# 4             5     Adelie  Torgersen            36.7           19.3
# ..          ...        ...        ...             ...            ...
# 339         340  Chinstrap      Dream            55.8           19.8
# 340         341  Chinstrap      Dream            43.5           18.1
# 341         342  Chinstrap      Dream            49.6           18.2
# 342         343  Chinstrap      Dream            50.8           19.0
# 343         344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# ...

# %% [markdown]
# **2.head**

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# **3.tail**

# %%
df.tail()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male

# %% [markdown]
# **4.info**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# **5.shape**

# %%
df.shape
# Out:
# (344, 7)

# %% [markdown]
# **6.size**

# %%
df.size
# Out:
# 2408

# %% [markdown]
# **7.describe**

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
#
#                       75%     max
# bill_length_mm       48.5    59.6
# bill_depth_mm        18.7    21.5
# flipper_length_mm   213.0   231.0
# body_mass_g        4750.0  6300.0

# %% [markdown]
# **8.sample**

# %%
#choose n number of random sample from the dataset
a=df.sample(n=10)
a
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 341     Gentoo     Biscoe            50.4           15.7              222.0
# 97      Adelie      Dream            40.3           18.5              196.0
# 69      Adelie  Torgersen            41.8           19.4              198.0
# 23      Adelie     Biscoe            38.2           18.1              185.0
# 293     Gentoo     Biscoe            46.5           14.8              217.0
# 218  Chinstrap      Dream            50.8           19.0              210.0
# 322     Gentoo     Biscoe            47.2           15.5              215.0
# 180  Chinstrap      Dream            46.4           17.8              191.0
# 125     Adelie  Torgersen            40.6           19.0              199.0
# 281     Gentoo     Biscoe            46.2           14.9              221.0
#
#      body_mass_g     sex
# 341       5750.0    Male
# 97        4350.0    Male
# 69        4450.0    Male
# 23        3950.0    Male
# ...

# %% [markdown]
# **9.isna**

# %%
b=df.isna()
b
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False            True           True               True
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex
# 0          False  False
# 1          False  False
# 2          False  False
# ...

# %%
#how to find if there is any variables/column with missing value in it
c=df.isna().any()
c
# Out:
# species              False
# island               False
# bill_length_mm        True
# bill_depth_mm         True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %% [markdown]
# **10.isnull**

# %%
d=df.isnull()
d
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False            True           True               True
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex
# 0          False  False
# 1          False  False
# 2          False  False
# ...

# %%
e=df.isnull().sum()
e
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
f=df.isnull().sum().sum()
f
# Out:
# 19

# %% [markdown]
# **11.fillna**

# %%
g=df.fillna(value=0)
g
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             0.0            0.0                0.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             0.0            0.0                0.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
h=df.fillna(value=5)
h
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             5.0            5.0                5.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             5.0            5.0                5.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
i=df.fillna(method="pad")
i
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
j=df.fillna(method="bfill")
j
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen            36.7           19.3              193.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe            46.8           14.3              215.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
k=df.fillna(method="pad",axis=1)
k
# Out:
#     species     island bill_length_mm bill_depth_mm flipper_length_mm  \
# 0    Adelie  Torgersen           39.1          18.7             181.0
# 1    Adelie  Torgersen           39.5          17.4             186.0
# 2    Adelie  Torgersen           40.3          18.0             195.0
# 3    Adelie  Torgersen      Torgersen     Torgersen         Torgersen
# 4    Adelie  Torgersen           36.7          19.3             193.0
# ..      ...        ...            ...           ...               ...
# 339  Gentoo     Biscoe         Biscoe        Biscoe            Biscoe
# 340  Gentoo     Biscoe           46.8          14.3             215.0
# 341  Gentoo     Biscoe           50.4          15.7             222.0
# 342  Gentoo     Biscoe           45.2          14.8             212.0
# 343  Gentoo     Biscoe           49.9          16.1             213.0
#
#     body_mass_g        sex
# 0        3750.0       Male
# 1        3800.0     Female
# 2        3250.0     Female
# ...

# %%
l=df.fillna(method="bfill",axis=1)
l
# Out:
#     species     island bill_length_mm bill_depth_mm flipper_length_mm  \
# 0    Adelie  Torgersen           39.1          18.7             181.0
# 1    Adelie  Torgersen           39.5          17.4             186.0
# 2    Adelie  Torgersen           40.3          18.0             195.0
# 3    Adelie  Torgersen            NaN           NaN               NaN
# 4    Adelie  Torgersen           36.7          19.3             193.0
# ..      ...        ...            ...           ...               ...
# 339  Gentoo     Biscoe            NaN           NaN               NaN
# 340  Gentoo     Biscoe           46.8          14.3             215.0
# 341  Gentoo     Biscoe           50.4          15.7             222.0
# 342  Gentoo     Biscoe           45.2          14.8             212.0
# 343  Gentoo     Biscoe           49.9          16.1             213.0
#
#     body_mass_g     sex
# 0        3750.0    Male
# 1        3800.0  Female
# 2        3250.0  Female
# 3           NaN     NaN
# ...

# %%
m=df.fillna({"bill_length_mm":"abcd"})
m
# Out:
#     species     island bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen           39.1           18.7              181.0
# 1    Adelie  Torgersen           39.5           17.4              186.0
# 2    Adelie  Torgersen           40.3           18.0              195.0
# 3    Adelie  Torgersen           abcd            NaN                NaN
# 4    Adelie  Torgersen           36.7           19.3              193.0
# ..      ...        ...            ...            ...                ...
# 339  Gentoo     Biscoe           abcd            NaN                NaN
# 340  Gentoo     Biscoe           46.8           14.3              215.0
# 341  Gentoo     Biscoe           50.4           15.7              222.0
# 342  Gentoo     Biscoe           45.2           14.8              212.0
# 343  Gentoo     Biscoe           49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
n=df.fillna({"bill_length_mm":"abcd","bill_depth_mm":"efgh"})
n
# Out:
#     species     island bill_length_mm bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen           39.1          18.7              181.0
# 1    Adelie  Torgersen           39.5          17.4              186.0
# 2    Adelie  Torgersen           40.3          18.0              195.0
# 3    Adelie  Torgersen           abcd          efgh                NaN
# 4    Adelie  Torgersen           36.7          19.3              193.0
# ..      ...        ...            ...           ...                ...
# 339  Gentoo     Biscoe           abcd          efgh                NaN
# 340  Gentoo     Biscoe           46.8          14.3              215.0
# 341  Gentoo     Biscoe           50.4          15.7              222.0
# 342  Gentoo     Biscoe           45.2          14.8              212.0
# 343  Gentoo     Biscoe           49.9          16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# ...

# %%
o=df.fillna(value=df["bill_length_mm"]).mean()
o
# Out:
# bill_length_mm         43.921930
# bill_depth_mm          17.151170
# flipper_length_mm     200.915205
# body_mass_g          4201.754386
# dtype: float64

# %%
p=df.fillna(value=df["bill_length_mm"]).max()
p
# Out:
# species                 Gentoo
# island               Torgersen
# bill_length_mm            59.6
# bill_depth_mm             21.5
# flipper_length_mm        231.0
# body_mass_g             6300.0
# dtype: object

# %%
q=df.fillna(value=df["bill_length_mm"]).min()
q
# Out:
# species              Adelie
# island               Biscoe
# bill_length_mm         32.1
# bill_depth_mm          13.1
# flipper_length_mm     172.0
# body_mass_g          2700.0
# dtype: object

# %% [markdown]
# **12.drop**

# %%
df1=df.drop("bill_length_mm",axis=1) 
df1     #remove one column
# Out:
#     species     island  bill_depth_mm  flipper_length_mm  body_mass_g     sex
# 0    Adelie  Torgersen           18.7              181.0       3750.0    Male
# 1    Adelie  Torgersen           17.4              186.0       3800.0  Female
# 2    Adelie  Torgersen           18.0              195.0       3250.0  Female
# 3    Adelie  Torgersen            NaN                NaN          NaN     NaN
# 4    Adelie  Torgersen           19.3              193.0       3450.0  Female
# ..      ...        ...            ...                ...          ...     ...
# 339  Gentoo     Biscoe            NaN                NaN          NaN     NaN
# 340  Gentoo     Biscoe           14.3              215.0       4850.0  Female
# 341  Gentoo     Biscoe           15.7              222.0       5750.0    Male
# 342  Gentoo     Biscoe           14.8              212.0       5200.0  Female
# 343  Gentoo     Biscoe           16.1              213.0       5400.0    Male
#
# [344 rows x 6 columns]

# %%
df2=df.drop(["bill_length_mm","bill_depth_mm"],axis=1)   #remove multiple column
df2
# Out:
#     species     island  flipper_length_mm  body_mass_g     sex
# 0    Adelie  Torgersen              181.0       3750.0    Male
# 1    Adelie  Torgersen              186.0       3800.0  Female
# 2    Adelie  Torgersen              195.0       3250.0  Female
# 3    Adelie  Torgersen                NaN          NaN     NaN
# 4    Adelie  Torgersen              193.0       3450.0  Female
# ..      ...        ...                ...          ...     ...
# 339  Gentoo     Biscoe                NaN          NaN     NaN
# 340  Gentoo     Biscoe              215.0       4850.0  Female
# 341  Gentoo     Biscoe              222.0       5750.0    Male
# 342  Gentoo     Biscoe              212.0       5200.0  Female
# 343  Gentoo     Biscoe              213.0       5400.0    Male
#
# [344 rows x 5 columns]

# %%
df3=df.drop([1],axis=0)      #remove one row index wise
df3
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 2         3250.0  Female
# ...

# %%
df4=df.drop([2,4],axis=0)   #remove multiple row
df4
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df5=df.drop(index=[2,4])  # direct index through remove row
df5
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df6=df.drop(columns=["bill_length_mm","bill_depth_mm"])
df6
# Out:
#     species     island  flipper_length_mm  body_mass_g     sex
# 0    Adelie  Torgersen              181.0       3750.0    Male
# 1    Adelie  Torgersen              186.0       3800.0  Female
# 2    Adelie  Torgersen              195.0       3250.0  Female
# 3    Adelie  Torgersen                NaN          NaN     NaN
# 4    Adelie  Torgersen              193.0       3450.0  Female
# ..      ...        ...                ...          ...     ...
# 339  Gentoo     Biscoe                NaN          NaN     NaN
# 340  Gentoo     Biscoe              215.0       4850.0  Female
# 341  Gentoo     Biscoe              222.0       5750.0    Male
# 342  Gentoo     Biscoe              212.0       5200.0  Female
# 343  Gentoo     Biscoe              213.0       5400.0    Male
#
# [344 rows x 5 columns]

# %%
df7=df.drop(index=[2,4],columns=["bill_length_mm","bill_depth_mm"])  #at time remove rows and columns mention index and columns
df7
# Out:
#     species     island  flipper_length_mm  body_mass_g     sex
# 0    Adelie  Torgersen              181.0       3750.0    Male
# 1    Adelie  Torgersen              186.0       3800.0  Female
# 3    Adelie  Torgersen                NaN          NaN     NaN
# 5    Adelie  Torgersen              190.0       3650.0    Male
# 6    Adelie  Torgersen              181.0       3625.0  Female
# ..      ...        ...                ...          ...     ...
# 339  Gentoo     Biscoe                NaN          NaN     NaN
# 340  Gentoo     Biscoe              215.0       4850.0  Female
# 341  Gentoo     Biscoe              222.0       5750.0    Male
# 342  Gentoo     Biscoe              212.0       5200.0  Female
# 343  Gentoo     Biscoe              213.0       5400.0    Male
#
# [342 rows x 5 columns]

# %%
df8=df.drop(index=[2,4,345],columns=["bill_length_mm","bill_depth_mm"],errors="ignore") #345 not present row ,error not showing
df8
# Out:
#     species     island  flipper_length_mm  body_mass_g     sex
# 0    Adelie  Torgersen              181.0       3750.0    Male
# 1    Adelie  Torgersen              186.0       3800.0  Female
# 3    Adelie  Torgersen                NaN          NaN     NaN
# 5    Adelie  Torgersen              190.0       3650.0    Male
# 6    Adelie  Torgersen              181.0       3625.0  Female
# ..      ...        ...                ...          ...     ...
# 339  Gentoo     Biscoe                NaN          NaN     NaN
# 340  Gentoo     Biscoe              215.0       4850.0  Female
# 341  Gentoo     Biscoe              222.0       5750.0    Male
# 342  Gentoo     Biscoe              212.0       5200.0  Female
# 343  Gentoo     Biscoe              213.0       5400.0    Male
#
# [342 rows x 5 columns]

# %%
df9=pd.read_csv("penguins.project.csv",index_col=["island","sex"])
df9
# Out:
#                   Unnamed: 0    species  bill_length_mm  bill_depth_mm  \
# island    sex
# Torgersen male             1     Adelie            39.1           18.7
#           female           2     Adelie            39.5           17.4
#           female           3     Adelie            40.3           18.0
#           NaN              4     Adelie             NaN            NaN
#           female           5     Adelie            36.7           19.3
# ...                      ...        ...             ...            ...
# Dream     male           340  Chinstrap            55.8           19.8
#           female         341  Chinstrap            43.5           18.1
#           male           342  Chinstrap            49.6           18.2
#           male           343  Chinstrap            50.8           19.0
#           female         344  Chinstrap            50.2           18.7
#
#                   flipper_length_mm  body_mass_g  year
# island    sex
# ...

# %% [markdown]
# **13.dropna**

# %%
df10=df.dropna()     # remove NA rows
df10
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df11=df.dropna(how="all")    #remove when all rows are NA
df11
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df12=df.dropna(how="any")    #remove when any rows are NA
df12
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# **13.replace**

# %%
df13=df.replace(to_replace=np.nan,value=1234)     # NA=1234 replace
df13
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen          1234.0         1234.0             1234.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe          1234.0         1234.0             1234.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df14=df.replace(to_replace=49.9,value=1234)   #replace any number=49.9=1234
df14
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe          1234.0           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# **14.groupby**

# %%
df15=df.groupby
df15
# Out:
# <bound method DataFrame.groupby of     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# ...

# %%
df16=df[["bill_length_mm","bill_depth_mm"]].groupby(df["body_mass_g"]).mean
df16
# Out:
# <bound method GroupBy.mean of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7fddcf908220>>

# %%
df17=df[["bill_length_mm","bill_depth_mm"]].groupby(df["body_mass_g"]).sum
df17
# Out:
# <bound method GroupBy.sum of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7fddcf908be0>>

# %% [markdown]
# **15.count**

# %%
df18=df.count
df18
# Out:
# <bound method DataFrame.count of     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# ...

# %%
df19=df.count()
df19
# Out:
# species              344
# island               344
# bill_length_mm       342
# bill_depth_mm        342
# flipper_length_mm    342
# body_mass_g          342
# sex                  333
# dtype: int64

# %% [markdown]
# **16.nunique**

# %%
#find no of distint values.this is an imp function as it will directly tell you how many categorial variables are there in your daset

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df20=df.nunique()
df20
# Out:
# species                3
# island                 3
# bill_length_mm       164
# bill_depth_mm         80
# flipper_length_mm     55
# body_mass_g           94
# sex                    2
# dtype: int64

# %% [markdown]
# **17.columns**

# %%
#get the names of the column
df21=df.columns
df21
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %% [markdown]
# **18 nsmallest and nlargest**

# %%
#get the nsmallest or nlargest values from a column
df22=df.nsmallest(10,"bill_length_mm")
df22
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 142  Adelie      Dream            32.1           15.5              188.0
# 98   Adelie      Dream            33.1           16.1              178.0
# 70   Adelie  Torgersen            33.5           19.0              190.0
# 92   Adelie      Dream            34.0           17.1              185.0
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 18   Adelie  Torgersen            34.4           18.4              184.0
# 54   Adelie     Biscoe            34.5           18.1              187.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# 80   Adelie  Torgersen            34.6           17.2              189.0
# 52   Adelie     Biscoe            35.0           17.9              190.0
#
#      body_mass_g     sex
# 142       3050.0  Female
# 98        2900.0  Female
# 70        3600.0  Female
# 92        3400.0  Female
# 8         3475.0     NaN
# ...

# %%
df23=df.nlargest(10,"bill_length_mm")
df23
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 253     Gentoo  Biscoe            59.6           17.0              230.0
# 169  Chinstrap   Dream            58.0           17.8              181.0
# 321     Gentoo  Biscoe            55.9           17.0              228.0
# 215  Chinstrap   Dream            55.8           19.8              207.0
# 335     Gentoo  Biscoe            55.1           16.0              230.0
# 283     Gentoo  Biscoe            54.3           15.7              231.0
# 183  Chinstrap   Dream            54.2           20.8              201.0
# 191  Chinstrap   Dream            53.5           19.9              205.0
# 327     Gentoo  Biscoe            53.4           15.8              219.0
# 181  Chinstrap   Dream            52.8           20.0              205.0
#
#      body_mass_g     sex
# 253       6050.0    Male
# 169       3700.0  Female
# 321       5600.0    Male
# 215       4000.0    Male
# 335       5850.0    Male
# ...

# %% [markdown]
# **19.loc and iloc**

# %%
df24=df.loc[1:10,["bill_length_mm","bill_depth_mm"]]
df24
# Out:
#     bill_length_mm  bill_depth_mm
# 1             39.5           17.4
# 2             40.3           18.0
# 3              NaN            NaN
# 4             36.7           19.3
# 5             39.3           20.6
# 6             38.9           17.8
# 7             39.2           19.6
# 8             34.1           18.1
# 9             42.0           20.2
# 10            37.8           17.1

# %%
df25=df.iloc[1:10,[2,3]]
df25
# Out:
#    bill_length_mm  bill_depth_mm
# 1            39.5           17.4
# 2            40.3           18.0
# 3             NaN            NaN
# 4            36.7           19.3
# 5            39.3           20.6
# 6            38.9           17.8
# 7            39.2           19.6
# 8            34.1           18.1
# 9            42.0           20.2

# %% [markdown]
# **20.slice the data**

# %%
df26=df[1:10]
df26
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
# 7  Adelie  Torgersen            39.2           19.6              195.0
# 8  Adelie  Torgersen            34.1           18.1              193.0
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g     sex
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# 5       3650.0    Male
# 6       3625.0  Female
# 7       4675.0    Male
# 8       3475.0     NaN
# 9       4250.0     NaN

# %% [markdown]
# **21.sorting according to one column**

# %%
df27=df.sort_values(by="bill_length_mm",ascending=False)
df27
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 253     Gentoo     Biscoe            59.6           17.0              230.0
# 169  Chinstrap      Dream            58.0           17.8              181.0
# 321     Gentoo     Biscoe            55.9           17.0              228.0
# 215  Chinstrap      Dream            55.8           19.8              207.0
# 335     Gentoo     Biscoe            55.1           16.0              230.0
# ..         ...        ...             ...            ...                ...
# 70      Adelie  Torgersen            33.5           19.0              190.0
# 98      Adelie      Dream            33.1           16.1              178.0
# 142     Adelie      Dream            32.1           15.5              188.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 339     Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g     sex
# 253       6050.0    Male
# ...

# %%
df28=df.sort_values(by="bill_length_mm") #ascending order 
df28
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 142     Adelie      Dream            32.1           15.5              188.0
# 98      Adelie      Dream            33.1           16.1              178.0
# 70      Adelie  Torgersen            33.5           19.0              190.0
# 92      Adelie      Dream            34.0           17.1              185.0
# 8       Adelie  Torgersen            34.1           18.1              193.0
# ..         ...        ...             ...            ...                ...
# 321     Gentoo     Biscoe            55.9           17.0              228.0
# 169  Chinstrap      Dream            58.0           17.8              181.0
# 253     Gentoo     Biscoe            59.6           17.0              230.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 339     Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g     sex
# 142       3050.0  Female
# ...

# %% [markdown]
# **22.Query in dataframe**

# %%
df29=df.query("bill_length_mm>40")[:10]
df29
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 12  Adelie  Torgersen            41.1           17.6              182.0
# 17  Adelie  Torgersen            42.5           20.7              197.0
# 19  Adelie  Torgersen            46.0           21.5              194.0
# 26  Adelie     Biscoe            40.6           18.6              183.0
# 27  Adelie     Biscoe            40.5           17.9              187.0
# 29  Adelie     Biscoe            40.5           18.9              180.0
# 33  Adelie      Dream            40.9           18.9              184.0
# 37  Adelie      Dream            42.2           18.5              180.0
#
#     body_mass_g     sex
# 2        3250.0  Female
# 9        4250.0     NaN
# 12       3200.0  Female
# 17       4500.0    Male
# 19       4200.0    Male
# ...

# %%
df30=df.query("bill_length_mm>40")[:].shape
df30
# Out:
# (242, 7)

# %% [markdown]
# **23.get unique value from a column**

# %%
df31=df["bill_length_mm"].nunique()
df31
# Out:
# 164

# %% [markdown]
# **24.memory_usage**

# %%
#if you want to know how many space columns are taking into your computer then use memory usage

# %%
df32=df.memory_usage()
df32
# Out:
# Index                 128
# species              2752
# island               2752
# bill_length_mm       2752
# bill_depth_mm        2752
# flipper_length_mm    2752
# body_mass_g          2752
# sex                  2752
# dtype: int64

# %% [markdown]
# **25.reset and soet index**

# %%
df33=df=df.reset_index(drop=True)
df33
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df34=df.sort_index()
df34
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# **26.sorting values od dataframe**

# %%
#sorting asending
df35=df.bill_length_mm.sort_values()
df35
# Out:
# 142    32.1
# 98     33.1
# 70     33.5
# 92     34.0
# 8      34.1
#        ...
# 321    55.9
# 169    58.0
# 253    59.6
# 3       NaN
# 339     NaN
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
df36=df.bill_length_mm.sort_values().head(10)
df36
# Out:
# 142    32.1
# 98     33.1
# 70     33.5
# 92     34.0
# 8      34.1
# 18     34.4
# 54     34.5
# 80     34.6
# 14     34.6
# 100    35.0
# Name: bill_length_mm, dtype: float64

# %%
df37=df.bill_length_mm.sort_values(ascending=False).head()
df37
# Out:
# 253    59.6
# 169    58.0
# 321    55.9
# 215    55.8
# 335    55.1
# Name: bill_length_mm, dtype: float64

# %%
#sorting cplumns that has space
df38=df["bill_length_mm"].sort_values(ascending=False).head()
df38
# Out:
# 253    59.6
# 169    58.0
# 321    55.9
# 215    55.8
# 335    55.1
# Name: bill_length_mm, dtype: float64

# %%
#sorting the entire dataframe
df39=df.sort_values("bill_length_mm")
df39
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 142     Adelie      Dream            32.1           15.5              188.0
# 98      Adelie      Dream            33.1           16.1              178.0
# 70      Adelie  Torgersen            33.5           19.0              190.0
# 92      Adelie      Dream            34.0           17.1              185.0
# 8       Adelie  Torgersen            34.1           18.1              193.0
# ..         ...        ...             ...            ...                ...
# 321     Gentoo     Biscoe            55.9           17.0              228.0
# 169  Chinstrap      Dream            58.0           17.8              181.0
# 253     Gentoo     Biscoe            59.6           17.0              230.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 339     Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g     sex
# 142       3050.0  Female
# ...

# %% [markdown]
# **Grapth visualisation**

# %% [markdown]
# **1.replot**
# ****

# %%
A=sns.load_dataset("penguins").head(30)
A
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
A1=sns.relplot(x='bill_length_mm',y='body_mass_g',data=A)

# %%
A2=sns.relplot(x="bill_length_mm", y="island", data=A,kind='line')

# %% [markdown]
# **2.distribution plot/dist plot**

# %%
#distribution plot
A3=sns.distplot(df['bill_length_mm'])

# %% [markdown]
# **3.distplot**

# %%
A4=sns.distplot(A['bill_length_mm'],hist=True,kde=False)

# %%
A5=sns.distplot(A['bill_length_mm'],hist=True,kde=True)

# %%
A6=sns.distplot(A['bill_length_mm'],hist=False,kde=True)

# %%
A7=sns.distplot(A['bill_length_mm'],hist=False,kde=False)

# %%
A8=sns.distplot(A['bill_length_mm'],hist=False,kde=True,color='g')

# %% [markdown]
# **4.jointplot**

# %%
A9=sns.jointplot(x='bill_length_mm',y='island',data=A)

# %%
A10=sns.jointplot(A['bill_length_mm'],kind='kde')

# %% [markdown]
# **5.pairplot**

# %%
A11=sns.pairplot(A)

# %% [markdown]
# **6.boxplot**

# %%
A12=sns.boxplot(x='island',y='bill_length_mm',data=df)

# %%
A13=sns.boxplot(x='island',y='bill_length_mm',data=df)

# %% [markdown]
# **7.violinplot**

# %%
A14=sns.violinplot(x='island',y='bill_length_mm',data=df)

# %%
A15=sns.violinplot(x='island',y='bill_length_mm',data=df,hue='sex')

# %%
A16=sns.violinplot(x='island',y='bill_length_mm',data=df,hue='sex')

# %% [markdown]
# **8.regplot**

# %%
A17=sns.regplot(x='bill_length_mm',y='bill_depth_mm',data=df)

# %% [markdown]
# **9.heatmap**

# %%
A19=sns.heatmap(df.corr())

# %%
A20=sns.heatmap(df.corr(),cmap='tab20')

# %%
A21=sns.heatmap(df.corr(),cmap='tab20',annot=True)

# %%
A22=sns.heatmap(df.corr(),cmap='tab20',annot=True,linewidth=0.8,linecolor='black')

# %% [markdown]
# **10.lineplopt**

# %%
A23=sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=df)

# %%
A24=sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=df,hue="sex")

# %%
A25=sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=df,hue="sex",size=15)

# %%
A26=sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=df,hue="sex",style="sex")

# %%
A27=sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=df,hue="sex",style="sex",palette="Accent")

# %%
A28=sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=df,hue="sex",style="sex",palette="Accent",markers=["o",">"])

# %%
A29=sns.load_dataset("penguins").head(40)
A29
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=A29,hue="sex",style="sex",palette="Accent",markers=["o",">"])
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
A30=sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=A29,hue="sex",style="sex",palette="Accent",markers=["o",">"],dashes=False)
A30
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
A31=sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=A29,hue="sex",style="sex",palette="Accent",markers=["o",">"],dashes=False,legend=False)
A31
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
A32=sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=A29,hue="sex",style="sex",palette="Accent",markers=["o",">"],dashes=False,legend=False)
A32
plt.grid()
plt.title("python")
plt.show()

# %% [markdown]
# **11.histogram plot**

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
A33=sns.displot(df["bill_length_mm"])
A33
plt.show()

# %%
A34=sns.displot(df["flipper_length_mm"])
A34
plt.show()

# %%
A35=sns.displot(df["flipper_length_mm"],bins=[170,180,190,200,210,220,230,240])
A35
plt.show()

# %%
A36=sns.displot(df["flipper_length_mm"],bins=[170,180,190,200,210,220,230,240],kde=True)
A36
plt.show()

# %%
A37=sns.displot(df["flipper_length_mm"],bins=[170,180,190,200,210,220,230,240],kde=True,rug=True)
A37
plt.show()

# %%
A38=sns.displot(df["flipper_length_mm"],bins=[170,180,190,200,210,220,230,240],kde=True,rug=True,color="purple")
A38
plt.show()

# %%
A39=sns.displot(df["flipper_length_mm"],kde=True,rug=True,color="purple",log_scale=True)
A39
plt.show()

# %% [markdown]
# **12.bar plot**

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
A40=sns.barplot(x=df.island,y=df.bill_length_mm)
A40
# Out:
# <Axes: xlabel='island', ylabel='bill_length_mm'>

# %%
A41=sns.barplot(x=A29.island,y=A29.bill_length_mm)
A41
plt.show()

# %%
A42=sns.barplot(x="island",y="bill_length_mm",data=A29)
A42
plt.show()

# %%
A43=sns.barplot(x="island",y="bill_length_mm",data=A29,hue="sex")
A43
plt.show()

# %%
A44=sns.barplot(x="island",y="bill_length_mm",data=A29,hue="sex",saturation=.3)
A44
plt.show()

# %%
A45=sns.set(style="darkgrid")
A45=sns.barplot(x="island",y="bill_length_mm",data=A29,hue="sex",saturation=12)
plt.show()

# %%
A46=sns.set(style="dark")
A46=sns.barplot(x="island",y="bill_length_mm",data=A29,hue="sex",saturation=12)
plt.show()

# %%
A47=sns.barplot(x="island",y="bill_length_mm",data=A29,hue="sex",saturation=12,capsize=0.5)
plt.show()

# %%
A48=sns.barplot(x="island",y="bill_length_mm",data=A29,hue="sex",saturation=12,dodge=False)
plt.show()

# %%
A49=sns.barplot(x="island",y="bill_length_mm",data=A29,hue="sex",saturation=12,errcolor="r",errwidth=12)
plt.show()

# %%
A50=sns.barplot(x="island",y="bill_length_mm",hue="sex",data=A29,order=["Dream","Torgersen","Biscoe"],hue_order=["Female","Male"])
plt.show()

# %%
A51=sns.barplot(x="island",y="bill_length_mm",data=A29,hue="sex",order=["Dream","Torgersen","Biscoe"])
plt.show()

# %%
A52=sns.barplot(x="island",y="bill_length_mm",data=A29,hue="sex",order=["Dream","Torgersen","Biscoe"],ci=80,n_boot=4)
plt.show()

# %%
A53=sns.barplot(x="island",y="bill_length_mm",data=A29,hue="sex",order=["Dream","Torgersen","Biscoe"],ci=80,n_boot=4,palette="icefire")
plt.show()

# %%
A54=sns.barplot(x="bill_depth_mm",y="bill_length_mm",data=A29,orient="v")
plt.show()

# %%
A55=sns.barplot(x="bill_depth_mm",y="bill_length_mm",data=A29,orient="h")
plt.show()

# %%
A56=sns.barplot(x="island",y="bill_length_mm",data=A29,color="g")
plt.show()

# %% [markdown]
# **13.strip plot**

# %%
#strip plot vs scatter plot

# %%
A57=sns.stripplot(x="island",y="bill_depth_mm",data=A29,hue="sex")
plt.show()

# %%
A58=sns.stripplot(x="island",y="bill_depth_mm",data=A29,hue="sex",palette="rocket_r")
plt.show()

# %%
A59=sns.stripplot(x="island",y="bill_depth_mm",data=A29,hue="sex",palette="rocket_r",edgecolor="r",jitter=5)
plt.show()

# %%
A60=sns.stripplot(x="island",y="bill_depth_mm",data=A29,hue="sex",palette="rocket_r",edgecolor="r",jitter=2)
plt.show()

# %%
A61=sns.stripplot(x="island",y="bill_depth_mm",data=A29,hue="sex",palette="rocket_r",size=10)
plt.show()

# %%
A62=sns.stripplot(x="island",y="bill_depth_mm",data=A29,hue="sex",palette="rocket_r",size=10,marker="<",alpha=0.2)
plt.show()

# %%
A63=sns.stripplot(x=A29["bill_length_mm"])

# %%
A64=sns.stripplot(y=A29["bill_length_mm"])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=sns.load_dataset("penguins")

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# **14.cat plot**

# %%
A65=sns.catplot(x="bill_length_mm",y="bill_depth_mm",data=A29)
A65

# %%
#cat plot in seaborn
#1.stripplot()-with kind="strip"
#2.swarmplot-

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
A66=sns.catplot(x="bill_length_mm",y="bill_depth_mm",data=A29)
A66
plt.show()

# %%
df=sns.load_dataset('penguins')

# %%
A67=sns.load_dataset('penguins').head(20)
A67
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
A67
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
A68=sns.catplot(x="bill_length_mm",y="bill_depth_mm",data=A67)
A68
plt.show()

# %%
A69=sns.catplot(x="bill_length_mm",y="bill_depth_mm",data=A67,hue="sex")
A69
plt.show()

# %%
A69=sns.catplot(x="bill_length_mm",y="bill_depth_mm",data=A67,hue="sex")
A69

plt.show()

# %%
A70=sns.catplot(x="bill_length_mm",y="bill_depth_mm",data=A67,hue="sex",palette="BuPu")
A70
plt.show()

# %%
A71=sns.catplot(x="bill_length_mm",y="bill_depth_mm",data=A67,hue="sex",palette="Oranges",height=5)
A71
plt.show()

# %%
A72=sns.catplot(x="bill_length_mm",y="bill_depth_mm",data=A67,hue="sex",palette="Oranges",kind="bar")
A72
plt.show()

# %%
A73=sns.catplot(x="bill_length_mm",y="bill_depth_mm",data=A67,hue="sex",palette="Oranges",kind="point")
A73
plt.show()

# %%
A74=sns.catplot(x="bill_length_mm",y="bill_depth_mm",data=A29,hue="sex",palette="Oranges",kind="box")
A74
plt.show()

# %%
A75=sns.catplot(x="bill_length_mm",y="bill_depth_mm",data=A29,hue="sex",palette="Oranges",kind="boxen")
A75
plt.show()

# %% [markdown]
# **15.Count plot**

# %%
#count plot vs  bar plot

# %%
B=sns.load_dataset("penguins").head(10)
B
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
# 7  Adelie  Torgersen            39.2           19.6              195.0
# 8  Adelie  Torgersen            34.1           18.1              193.0
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# 5       3650.0    Male
# ...

# %%
A76=sns.countplot(x="sex",data=B)
plt.show()

# %%
A76=sns.countplot(x="sex",data=B,hue="body_mass_g")
plt.show()

# %%
A77=sns.countplot(y="sex",data=B,hue="body_mass_g")
plt.show()

# %%
A78=sns.countplot(y="sex",data=B,hue="body_mass_g",palette="cool")
plt.show()

# %%
A79=sns.countplot(y="sex",data=B,hue="body_mass_g",color="b")
plt.show()

# %% [markdown]
# # **16.scatter plot**

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
A
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=df)
plt.show()

# %%
sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=A,hue="sex",style="sex",size="sex",sizes=(100,40),palette="gist_ncar")
plt.show()

# %% [markdown]
# **17.PLOT**

# %%
A.plot(kind="line",color=["red","blue","brown"])
plt.title("python")
plt.show()

# %%
A
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %% [markdown]
# **18.pie chart**

# %%
A=df["bill_length_mm"]
PK=A.head(3)
PK
# Out:
# 0    39.1
# 1    39.5
# 2    40.3
# Name: bill_length_mm, dtype: float64

# %%
plt.pie(PK,labels=PK)
plt.show()
